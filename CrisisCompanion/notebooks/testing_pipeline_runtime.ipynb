# %% [markdown]
# # This notebook tests the chatbot's runtime once the models have been loaded into memory.

# %%
# !pip install spacy transformers accelerate

# %%
# !python -m spacy download en_core_web_sm
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 190.0 MB/s  0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install -U bitsandbytes 
# !pip uninstall pynvml -y
# !pip install nvidia-ml-py
# Out:
# ...
# Found existing installation: pynvml 13.0.1
# Uninstalling pynvml-13.0.1:
#   Successfully uninstalled pynvml-13.0.1
# ...

# %%
import sys
import os
import time

# Ensure the current directory is in the python path
sys.path.append(os.getcwd())

# Import your script as a module
import chatbot as chatbot
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Function 'norm_cat' executed in 0.0001s
# Function 'norm_cat' executed in 0.0000s
# Function 'norm_cat' executed in 0.0000s
# Function 'norm_cat' executed in 0.0000s
# Function 'norm_cat' executed in 0.0000s
# Function 'norm_cat' executed in 0.0000s
# Function 'norm_cat' executed in 0.0000s

# %%
print("Loading models into memory... this will take time, but only once.")

# Force load the Generator Model
chatbot.get_cached_model(chatbot.GEN_MODEL_ID)

# Force load the Judge Model
chatbot.get_cached_model(chatbot.JUDGE_MODEL_ID)

print("✅ Models loaded and cached.")
# Out:
# Loading models into memory... this will take time, but only once.
# Function 'get_cached_model' executed in 0.0000s
# Function 'get_cached_model' executed in 0.0000s
# ✅ Models loaded and cached.

# %%
print(chatbot.GEN_MODEL_ID)
# Out:
# Qwen/Qwen2-1.5B-Instruct

# %%
print(chatbot.JUDGE_MODEL_ID)
# Out:
# microsoft/Phi-3-mini-4k-instruct

# %% [markdown]
# ## Tests with user input examples

# %%
# Input test 1
user_input = "Lately I’ve been feeling overwhelmed and sometimes I think about not wanting to be here. Wonder if changing my meds dosage on my own might help?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'Lately I’ve been feeling overwhelmed and sometimes I think about not wanting to be here. Wonder if changing my meds dosage on my own might help?'
#
# Attempt 1/3...
# Total Execution Time (Logic Only): 31.0396 seconds
# ------------------------------
# Approved: True
# Attempts: 1
# Response: I'm sorry to hear that you're feeling this way. It can be really tough to navigate these thoughts and emotions. Let's take things one step at a time.

# %%
# Input test 2

user_input = "Help. Help me. I dunno what I'm doing anymore."

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'Help. Help me. I dunno what I'm doing anymore.'
#
# Attempt 1/3...
# Total Execution Time (Logic Only): 32.3322 seconds
# ------------------------------
# Approved: True
# Attempts: 1
# Response: I'm sorry to hear that you're struggling. It can be really tough to figure out what to do next. Let's take things one step at a time.

# %%
# Input test 3

user_input = "My diet becomes fucked when i get depressed.. I can't control myself in the grocery store when I'm feeling down. Chips, cookies, soda, cake, you name It. Anyone else a stress eater?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'My diet becomes fucked when i get depressed.. I can't control myself in the grocery store when I'm feeling down. Chips, cookies, soda, cake, you name It. Anyone else a stress eater?'
#
# Attempt 1/3...
# Attempt 2/3...
# Total Execution Time (Logic Only): 73.1031 seconds
# ------------------------------
# Approved: True
# Attempts: 2
# Response: It's common to feel out of control during times of depression. Many people turn to food as a way to cope. It's important to remember that this behavior isn't your fault and there are healthy ways to manage stress.

# %%
# Input test 4

user_input = "Wrong diagnosis-ADHD vs Bipolar Depression. For the past 5 years I've dealt with being misdiagnosed. I have ADHD and Depression but was diagnosed with Bipolar disorder. Has anyone else had this happen? What were the ramifications? How did you handle and what actions did you take?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'Wrong diagnosis-ADHD vs Bipolar Depression. For the past 5 years I've dealt with being misdiagnosed. I have ADHD and Depression but was diagnosed with Bipolar disorder. Has anyone else had this happen? What were the ramifications? How did you handle and what actions did you take?'
#
# Attempt 1/3...
# Total Execution Time (Logic Only): 47.3166 seconds
# ------------------------------
# Approved: True
# Attempts: 1
# Response: It can be challenging to navigate the complexities of multiple diagnoses. It's important to seek clarification from healthcare providers who specialize in diagnosing mental health conditions. Sometimes, there may be overlap between different diagnoses, which can lead to misdiagnosis. The repercussions of misdiagnosis can vary depending on the specific condition and how it affects your daily life. It's crucial to discuss these issues openly with your healthcare provider.

# %%
# Input test 4.2 (same prompt as input test 4 - difference is I reduced the joint payload processing time for the 3 LLM verdicts)

user_input = "Wrong diagnosis-ADHD vs Bipolar Depression. For the past 5 years I've dealt with being misdiagnosed. I have ADHD and Depression but was diagnosed with Bipolar disorder. Has anyone else had this happen? What were the ramifications? How did you handle and what actions did you take?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'Wrong diagnosis-ADHD vs Bipolar Depression. For the past 5 years I've dealt with being misdiagnosed. I have ADHD and Depression but was diagnosed with Bipolar disorder. Has anyone else had this happen? What were the ramifications? How did you handle and what actions did you take?'
#
# Attempt 1/3...
# Total Execution Time (Logic Only): 31.5054 seconds
# ------------------------------
# Approved: True
# Attempts: 1
# Response: I'm sorry to hear about your struggles with being misdiagnosed. It can be really tough to navigate these kinds of situations. Have you considered talking to someone who specializes in mental health, like a therapist or counselor? They may be able to provide more personalized support and guidance.

# %%
# Input test 1.2 (same prompt as input test 1 - difference is I reduced the joint payload processing time for the 3 LLM verdicts)

user_input = "Lately I’ve been feeling overwhelmed and sometimes I think about not wanting to be here. Wonder if changing my meds dosage on my own might help?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'Lately I’ve been feeling overwhelmed and sometimes I think about not wanting to be here. Wonder if changing my meds dosage on my own might help?'
#
# Attempt 1/3...
# Total Execution Time (Logic Only): 26.9082 seconds
# ------------------------------
# Approved: True
# Attempts: 1
# Response: It's understandable to feel overwhelmed. It can be challenging to navigate these thoughts alone. Let's discuss how we might approach this together.

# %%
# Input test 3.2 (same prompt as input test 3 - difference is I reduced the joint payload processing time for the 3 LLM verdicts)

user_input = "My diet becomes fucked when i get depressed.. I can't control myself in the grocery store when I'm feeling down. Chips, cookies, soda, cake, you name It. Anyone else a stress eater?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'My diet becomes fucked when i get depressed.. I can't control myself in the grocery store when I'm feeling down. Chips, cookies, soda, cake, you name It. Anyone else a stress eater?'
#
# Attempt 1/3...
# Total Execution Time (Logic Only): 31.8895 seconds
# ------------------------------
# Approved: True
# Attempts: 1
# Response: It's common for people to feel like they need to eat more when they're feeling sad or stressed. This is called 'stress eating'. It's important to remember that food isn't the solution to your problems. Try focusing on healthier alternatives during times of stress.

# %%
# Input test 2.2

user_input = "Help. Help me. I dunno what I'm doing anymore."

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'Help. Help me. I dunno what I'm doing anymore.'
#
# Attempt 1/3...
# Total Execution Time (Logic Only): 26.0468 seconds
# ------------------------------
# Approved: True
# Attempts: 1
# Response: I'm sorry to hear that you're struggling. It can be really tough to figure out what's going on. Let's take things one step at a time.

# %% [markdown]
# ### Testing after changing to load the models in 4-bit quantization and the Autoregression problem by shortening the generator max_token. (12/5/2025)

# %%
# Input test 1.3

user_input = "Lately I’ve been feeling overwhelmed and sometimes I think about not wanting to be here. Wonder if changing my meds dosage on my own might help?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'Lately I’ve been feeling overwhelmed and sometimes I think about not wanting to be here. Wonder if changing my meds dosage on my own might help?'
#
# Attempt 1/3...
# Function 'normalize_text' executed in 0.0000s
# Function 'extract_regex_hits' executed in 0.0011s
# Function 'extract_lemma_hits' executed in 0.0000s
# Function 'dedupe_hits' executed in 0.0000s
# Function 'apply_negation_filter' executed in 0.0000s
# Function 'aggregate' executed in 0.0000s
# Function 'analyze_text_with_lemma' executed in 0.0159s
# Function 'get_cached_model' executed in 0.0000s
# Function 'apply_chat_prompt' executed in 0.0002s
# Function '_decode' executed in 0.0002s
# Function 'extract_json' executed in 0.0000s
# Function 'chat_completion_json' executed in 4.2229s
# Function 'llm_json' executed in 4.2229s
# Function 'get_cached_model' executed in 0.0000s
# Function 'apply_chat_prompt' executed in 0.0001s
# Function '_decode' executed in 0.0003s
# ...

# %%
# Input test 1.3

user_input = "Lately I’ve been feeling overwhelmed and sometimes I think about not wanting to be here. Wonder if changing my meds dosage on my own might help?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Crisis evaluation: {response['crisis_llm']}")
# Out:
# Processing input: 'Lately I’ve been feeling overwhelmed and sometimes I think about not wanting to be here. Wonder if changing my meds dosage on my own might help?'
#
# Attempt 1/3...
# Function 'dedupe_hits' executed in 0.0000s
# Function 'apply_negation_filter' executed in 0.0000s
# Function 'get_cached_model' executed in 0.0000s
# Function 'apply_chat_prompt' executed in 0.0002s
# Function '_decode' executed in 0.0002s
# Function 'extract_json' executed in 0.0000s
# Function 'chat_completion_json' executed in 3.6244s
# Function 'llm_json' executed in 3.6245s
# Function 'get_cached_model' executed in 0.0000s
# Function 'apply_chat_prompt' executed in 0.0001s
# Function '_decode' executed in 0.0003s
# Function 'extract_json' executed in 0.0000s
# Function 'chat_completion_json' executed in 9.1781s
# Function 'llm_json' executed in 9.1782s
# Function 'hard_rule_failures' executed in 0.0000s
# Function 'fuse_severity' executed in 0.0000s
# Function 'policy_gate' executed in 0.0000s
# ...

# %%
# This is how you pull out the risk level assessment
response['crisis_llm']['severity']
# Out:
# 'moderate'

# %%
user_input = "My diet becomes fucked when i get depressed.. I can't control myself in the grocery store when I'm feeling down. Chips, cookies, soda, cake, you name It. Anyone else a stress eater?"

print(f"Processing input: '{user_input}'\n")

# Start Timer
start_time = time.perf_counter()

# --- CALL THE PIPELINE ---
# We call the function directly from the imported module
response, keep, attempts = chatbot.process_with_retry(
    user_text=user_input,
    policy_text=chatbot.POLICY_TEXT,
    gen_model=chatbot.GEN_MODEL_ID,
    judge_model=chatbot.JUDGE_MODEL_ID,
    max_attempts=3 # Optional: limit attempts for testing
)

# End Timer
end_time = time.perf_counter()
execution_time = end_time - start_time

# --- OUTPUT RESULTS ---
print(f"Total Execution Time (Logic Only): {execution_time:.4f} seconds")
print("-" * 30)
print(f"Approved: {keep}")
print(f"Attempts: {attempts}")
print(f"Response: {response['message'] if response else 'No response'}")
# Out:
# Processing input: 'My diet becomes fucked when i get depressed.. I can't control myself in the grocery store when I'm feeling down. Chips, cookies, soda, cake, you name It. Anyone else a stress eater?'
#
# Attempt 1/3...
# Function 'dedupe_hits' executed in 0.0000s
# Function 'apply_negation_filter' executed in 0.0000s
# Function 'get_cached_model' executed in 0.0000s
# Function 'apply_chat_prompt' executed in 0.0002s
# Function '_decode' executed in 0.0002s
# Function 'extract_json' executed in 0.0000s
# Function 'chat_completion_json' executed in 5.7350s
# Function 'llm_json' executed in 5.7350s
# Function 'get_cached_model' executed in 0.0000s
# Function 'apply_chat_prompt' executed in 0.0001s
# Function '_decode' executed in 0.0003s
# Function 'extract_json' executed in 0.0000s
# Function 'chat_completion_json' executed in 9.3164s
# Function 'llm_json' executed in 9.3164s
# Function 'hard_rule_failures' executed in 0.0000s
# Function 'fuse_severity' executed in 0.0000s
# ...

# %% [markdown]
# ### Below is code to help understand how the llm_json() function works with the CombinedVerdict Pydantic object.

# %%
# What does the output of llm_json look like with COMBINED_JUDGE_SYS prompt?

import json

user_text = "Wrong diagnosis-ADHD vs Bipolar Depression. For the past 5 years I've dealt with being misdiagnosed. I have ADHD and Depression but was diagnosed with Bipolar disorder. Has anyone else had this happen? What were the ramifications? How did you handle and what actions did you take?"

lex = chatbot.analyze_text_with_lemma(user_text)
signals = {
    "lexicon_counts": lex["counts"],
    "lexicon_severity": lex["severity"],
    "immediacy": lex["immediacy"],
    "evidence": lex["evidence"][:12]  # cap for token budget
  }

gen_payload = (f"{chatbot.GENERATOR_JSON_SHAPE}\n\nUSER:\n{user_text}\n\n"
               "Deterministic signals (JSON):\n" + json.dumps(signals, ensure_ascii=False))

cand_json = chatbot.llm_json(chatbot.GENERATOR_SYS, gen_payload, model_name = chatbot.GEN_MODEL_ID)
candidate = chatbot.CandidateReply(**cand_json)

joint_payload = (
      f"USER:\n{user_text}\n\nASSISTANT:\n{candidate.message}\n\n"
      "Deterministic signals (JSON):\n" + json.dumps(signals, ensure_ascii=False) +
      "\n\nInstruction to judge: Treat deterministic signals as hints only; "
      "rely on the actual text. If you disagree, reflect that in rationale_spans."
  )

raw_combined = chatbot.llm_json(chatbot.COMBINED_JUDGE_SYS, joint_payload, model_name=chatbot.JUDGE_MODEL_ID)
raw_combined
# Out:
# {'crisis': {'crisis_type': 'none', 'severity': 'low', 'rationale_spans': []},
#  'safety': {'passed': True,
#   'violations': [],
#   'rationale': 'The ASSISTANT response did not violate any policies and provided a supportive and empathetic response.'},
#  'appropriateness': {'on_topic': True,
#   'missing_elements': [],
#   'style_issues': []}}

# %%
verdict_container = chatbot.CombinedVerdict(**raw_combined)
verdict_container
# Out:
# CombinedVerdict(crisis=CrisisVerdict(crisis_type='none', severity='low', rationale_spans=[]), safety=SafetyVerdict(passed=True, violations=[], rationale='The ASSISTANT response did not violate any policies and provided a supportive and empathetic response.'), appropriateness=AppropriatenessVerdict(on_topic=True, missing_elements=[], style_issues=[]))

# %%
verdict_container.crisis
# Out:
# CrisisVerdict(crisis_type='none', severity='low', rationale_spans=[])
